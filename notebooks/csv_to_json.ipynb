# %%
import json
import pandas as pd

# %%
fname = "../data/json/bns_sections.csv"

# %%
data = pd.read_csv(fname).map(
    lambda x : {"Section":x["Section"],"Description":x["Description"]}
)
data
# Out:
#      Chapter                                       Chapter_name  \
# 0          1                                        Preliminary
# 1          1                                        Preliminary
# 2          1                                        Preliminary
# 3          2                                     Of punishments
# 4          2                                     Of punishments
# ..       ...                                                ...
# 353       19  OF CRIMINAL INTIMIDATION, INSULT, ANNOYANCE, D...
# 354       19  OF CRIMINAL INTIMIDATION, INSULT, ANNOYANCE, D...
# 355       19                                      Of defamation
# 356       19  Of breach of contract to attend on and supply ...
# 357       20                                 REPEAL AND SAVINGS
#
#                                        Chapter_subtype  Section  \
# 0                                          Preliminary        1
# 1                                          Preliminary        2
# ...

# %%
with open("bns_sections.json","w") as f:
    json.dump(data,f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 with open("bns_sections.json","w") as f:
# ----> 2     json.dump(data,f)
#
# File D:\Python\Python312\Lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# ...
